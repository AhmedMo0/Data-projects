# %%
import pandas as pd
import requests
import os
import tweepy
import json

# %% [markdown]
# ## Gathering data

# %%
# read tiwtter archive to df
archive_df = pd.read_csv("twitter-archive-enhanced.csv")

#####

#download images_NL file and open as df
url= "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
r = requests.get(url)


if not os.path.isfile(url.split("/")[-1]):
    with open(url.split("/")[-1], mode="wb") as f:
        f.write(r.content)
image_p_df = pd.read_csv(url.split("/")[-1], sep="\t")


##########

###twitter api#####
'''consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
'''
#################

#make a df of favorit_count and retweet_count

rt=[]
favb=[]
i_d=[]
with open("tweet-json","r") as file:
    
    for l in file:
        to_dic = json.loads(l)
        rt.append(to_dic['retweet_count'])
        favb.append(to_dic['favorite_count'])
        i_d.append(to_dic['id'])
        
        

api_df =pd.DataFrame({
    "id":i_d,
    "retweet":rt,
    "favb":favb
})
api_df = api_df.style.hide_index()

###############


    



















################
#get tweets from api
'''exp_tweet = api.get_status(891689557279858000, tweet_mode = 'extended')
content = exp_tweet._json
print(Content)

errors = []
#if not os.path.isfile('tweet_json.txt'):
with open ('tweet_json.txt', 'w') as file:
        
    for tweet_id in tarc['tweet_id']:
        try:
            status = api.get_status(tweet_id, wait_on_rate_limit=True, wait_on_rate_limit_notify=True, tweet_mode =
            'extended')
            json.dump(status._json, file)
            file.write('\n')
        except Exception as e:
            print("Error on tweet id {}".format(tweet_id) + ";" + str(e))
            errors.append(tweet_id)
'''
