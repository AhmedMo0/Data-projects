# %% [markdown]
# ## Warngling process table
# ### 1. [Gathering Data](#g_data)
# ### 2. [Assessing Data](#assess)
# ### 3. [Cleaning Data](#clean)
# ### 4. [Storing](#store)
# ### 5. [Data Analysis and Visualizations](#analysis)

# %%
import pandas as pd
import requests
import os
import tweepy
import json
import numpy as np
import re
# %matplotlib inline
import matplotlib.pyplot as plt

# %% [markdown]
# ## Gathering data
# <a id="g_data"></a>

# %%
# read tiwtter archive to df
archive_df = pd.read_csv("twitter-archive-enhanced.csv")



#download images_NL file and open as df

url= "https://d17h27t6h515a5.cloudfront.net/topher/2017/August/599fd2ad_image-predictions/image-predictions.tsv"
r = requests.get(url)

if not os.path.isfile(url.split("/")[-1]):
    with open(url.split("/")[-1], mode="wb") as f:
        f.write(r.content)
image_p_df = pd.read_csv(url.split("/")[-1], sep="\t")


###twitter api#####
'''consumer_key = ''
consumer_secret = ''
access_token = ''
access_secret = ''
auth = tweepy.OAuthHandler(consumer_key, consumer_secret)
auth.set_access_token(access_token, access_secret)
api = tweepy.API(auth, wait_on_rate_limit=True, wait_on_rate_limit_notify=True)
'''
#################

#import data from tweet-json file to df that consists of favorit_count&retweet_count&tweet id 

rt=[]
favb=[]
i_d=[]

with open("tweet-json","r") as file:
    
    for l in file:
        to_dic = json.loads(l)
        rt.append(to_dic['retweet_count'])
        favb.append(to_dic['favorite_count'])
        i_d.append(to_dic['id'])
        
        

json_df =pd.DataFrame({
    "tweet_id":i_d,
    "retweet_count":rt,
    "fav_count":favb
})

# %% [markdown]
# ## Assessing data
# <a id="assess"></a>

# %% [markdown]
# ## Quality issues
# ### - `Combleteness`
#     - missing(NaN) values in columns (in_reply_to_status_id,in_reply_to_user_id) and breed types
#     - missing values in name column that can get it from text
#     - tweets with no images
#     - datasets have retweets and replys data not only tweets
#
# ### - `Validity`
#     - not valid names (the, a, an, by)
#     - there are tweets with out images (expanded_urls and retweet url          are empty)
#     - there are retweets in all datasets in this data (
#       retweeted_status_id           181 non-null float64
#       retweeted_status_user_id      181 non-null float64
#       retweeted_status_timestamp    181 non-null object )
#
#     - there are replys in all datasets in this data (
#       in_reply_to_status_id           78 non-null float64
#       in_reply_to_user_id      78 non-null float64 )
#     - rating_numenator col doesn't match with rate in text (ex: index 47) and there is outliers
#     - denominator not equal 10 (ex: index 435)
#
# ### - `Accuracy`
#     - name values don't match with names in text
#     - rating_numenator col doesn't match with rate in text (ex: index 47) and there is outliers
#     - source column is an HTML tag
#
#
# ### - `Consistency`
#     -	tweet_id dtype is int
#     -	unused columns like (denominator, expanded_urls, retweeted_status_id, retweeted_status_user_id, in_reply_to_status_id, in_reply_to_user_id)
#     -	unused columns like img_num and p_n_prediction in image_p df
#
#
#
#
#
# ## - Tideness issues
#
#     - values are column names in archive_df (ex: doggo, floofer, pupper, puppo  should be combined into a single column as this is one variable that identify type of dog)
#
#     - values are column names in image_p_df (ex: p1, p1_dog, p1_conf. p2, p2_dog,p2_conf,p3,p3_dog,p3_conf  all these columns should be in only three columns )
#
#     - Information about one type of observational unit (tweets) is spread across three different DataFrames. So these three DataFrames should be merged as they are part of the same observational unit.

# %%
archive_df.head()
# Out:
#              tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 0  892420643555336193                    NaN                  NaN
# 1  892177421306343426                    NaN                  NaN
# 2  891815181378084864                    NaN                  NaN
# 3  891689557279858688                    NaN                  NaN
# 4  891327558926688256                    NaN                  NaN
#
#                    timestamp  \
# 0  2017-08-01 16:23:56 +0000
# 1  2017-08-01 00:17:27 +0000
# 2  2017-07-31 00:18:03 +0000
# 3  2017-07-30 15:58:51 +0000
# 4  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  retweeted_status_id  \
# 0  This is Phineas. He's a mystical boy. Only eve...                  NaN
# 1  This is Tilly. She's just checking pup on you....                  NaN
# 2  This is Archie. He is a rare Norwegian Pouncin...                  NaN
# 3  This is Darla. She commenced a snooze mid meal...                  NaN
# 4  This is Franklin. He would like you to stop ca...                  NaN
#
#    retweeted_status_user_id retweeted_status_timestamp  \
# 0                       NaN                        NaN
# 1                       NaN                        NaN
# 2                       NaN                        NaN
# 3                       NaN                        NaN
# 4                       NaN                        NaN
#
#                                        expanded_urls  rating_numerator  \
# 0  https://twitter.com/dog_rates/status/892420643...                13
# 1  https://twitter.com/dog_rates/status/892177421...                13
# 2  https://twitter.com/dog_rates/status/891815181...                12
# 3  https://twitter.com/dog_rates/status/891689557...                13
# 4  https://twitter.com/dog_rates/status/891327558...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %%
#tweets that have no images
archive_df[archive_df["expanded_urls"].isna()].head()
# Out:
#                tweet_id  in_reply_to_status_id  in_reply_to_user_id  \
# 30   886267009285017600           8.862664e+17         2.281182e+09
# 55   881633300179243008           8.816070e+17         4.738443e+07
# 64   879674319642796034           8.795538e+17         3.105441e+09
# 113  870726314365509632           8.707262e+17         1.648776e+07
# 148  863427515083354112           8.634256e+17         7.759620e+07
#
#                      timestamp  \
# 30   2017-07-15 16:51:35 +0000
# 55   2017-07-02 21:58:53 +0000
# 64   2017-06-27 12:14:36 +0000
# 113  2017-06-02 19:38:25 +0000
# 148  2017-05-13 16:15:35 +0000
#
#                                                 source  \
# 30   <a href="http://twitter.com/download/iphone" r...
# 55   <a href="http://twitter.com/download/iphone" r...
# 64   <a href="http://twitter.com/download/iphone" r...
# 113  <a href="http://twitter.com/download/iphone" r...
# 148  <a href="http://twitter.com/download/iphone" r...
#
#                                                   text  retweeted_status_id  \
# 30   @NonWhiteHat @MayhewMayhem omg hello tanner yo...                  NaN
# 55   @roushfenway These are good dogs but 17/10 is ...                  NaN
# 64                     @RealKentMurphy 14/10 confirmed                  NaN
# 113  @ComplicitOwl @ShopWeRateDogs &gt;10/10 is res...                  NaN
# 148  @Jack_Septic_Eye I'd need a few more pics to p...                  NaN
#
#      retweeted_status_user_id retweeted_status_timestamp expanded_urls  \
# 30                        NaN                        NaN           NaN
# 55                        NaN                        NaN           NaN
# 64                        NaN                        NaN           NaN
# 113                       NaN                        NaN           NaN
# 148                       NaN                        NaN           NaN
#
#      rating_numerator  rating_denominator  name doggo floofer pupper puppo
# 30                 12                  10  None  None    None   None  None
# 55                 17                  10  None  None    None   None  None
# 64                 14                  10  None  None    None   None  None
# 113                10                  10  None  None    None   None  None
# 148                12                  10  None  None    None   None  None

# %%
archive_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2356 entries, 0 to 2355
# Data columns (total 17 columns):
# tweet_id                      2356 non-null int64
# in_reply_to_status_id         78 non-null float64
# in_reply_to_user_id           78 non-null float64
# timestamp                     2356 non-null object
# source                        2356 non-null object
# text                          2356 non-null object
# retweeted_status_id           181 non-null float64
# retweeted_status_user_id      181 non-null float64
# retweeted_status_timestamp    181 non-null object
# expanded_urls                 2297 non-null object
# rating_numerator              2356 non-null int64
# rating_denominator            2356 non-null int64
# name                          2356 non-null object
# doggo                         2356 non-null object
# floofer                       2356 non-null object
# pupper                        2356 non-null object
# puppo                         2356 non-null object
# dtypes: float64(4), int64(3), object(10)
# memory usage: 313.0+ KB

# %%
image_p_df.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %%
image_p_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2075 entries, 0 to 2074
# Data columns (total 12 columns):
# tweet_id    2075 non-null int64
# jpg_url     2075 non-null object
# img_num     2075 non-null int64
# p1          2075 non-null object
# p1_conf     2075 non-null float64
# p1_dog      2075 non-null bool
# p2          2075 non-null object
# p2_conf     2075 non-null float64
# p2_dog      2075 non-null bool
# p3          2075 non-null object
# p3_conf     2075 non-null float64
# p3_dog      2075 non-null bool
# dtypes: bool(3), float64(3), int64(2), object(4)
# memory usage: 152.1+ KB

# %%
json_df.head()
# Out:
#              tweet_id  retweet_count  fav_count
# 0  892420643555336193           8853      39467
# 1  892177421306343426           6514      33819
# 2  891815181378084864           4328      25461
# 3  891689557279858688           8964      42908
# 4  891327558926688256           9774      41048

# %%
json_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2354 entries, 0 to 2353
# Data columns (total 3 columns):
# tweet_id         2354 non-null int64
# retweet_count    2354 non-null int64
# fav_count        2354 non-null int64
# dtypes: int64(3)
# memory usage: 55.2 KB

# %% [markdown]
# ## Cleaning data
# <a id="clean"></a>

# %% [markdown]
#  ### `Define`
#
#  - remove retweets, replys and expanded_urls from all datasets
#  - drop columns:
#      -  expanded_urls,
#      -  in_reply_to_status_id,
#      -  in_reply_to_user_id,
#      -  retweeted_status_timestamp,
#      -  retweeted_status_user_id,
#      -  retweeted_status_id

# %% [markdown]
# ### `Code`

# %%
# copy all datasets
clean_archive = archive_df.copy()
clean_image_p = image_p_df.copy()
clean_json = json_df.copy()


#drop tweets that with no images
clean_archive = clean_archive[~clean_archive["expanded_urls"].isna()]

# creating a list of tweet_ids with images "tweets_with_image" and confirming its length
tweets_with_image = list(clean_image_p.tweet_id.unique())

# Cleaning in action ;)
clean_archive = clean_archive[clean_archive.tweet_id.isin(tweets_with_image)]


#get retweets
retweets_l = clean_archive.retweeted_status_id.notnull()

#drop retweets observations
clean_archive = clean_archive[~retweets_l]

#get replys
replys_l = clean_archive.in_reply_to_status_id.notnull()

#drop replys observations
clean_archive = clean_archive[~replys_l]


# Dropping the retweets and replies ids from the image prediction dataframe
clean_image_p = clean_image_p[~np.logical_not(clean_image_p.tweet_id.isin(list(clean_archive.tweet_id)))]

# Dropping the retweets and replies ids from json dataframe
clean_json = clean_json[~np.logical_not(clean_json.tweet_id.isin(list(clean_archive.tweet_id)))]

#Dropping reply and tweet columns 
clean_archive = clean_archive.drop(['retweeted_status_id','retweeted_status_user_id', 'retweeted_status_timestamp',\
                                   "in_reply_to_status_id","in_reply_to_user_id","expanded_urls"],axis=1)

# %% [markdown]
# ### `Test`

# %%
clean_archive.head()
# Out:
#              tweet_id                  timestamp  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000
# 1  892177421306343426  2017-08-01 00:17:27 +0000
# 2  891815181378084864  2017-07-31 00:18:03 +0000
# 3  891689557279858688  2017-07-30 15:58:51 +0000
# 4  891327558926688256  2017-07-29 16:00:24 +0000
#
#                                               source  \
# 0  <a href="http://twitter.com/download/iphone" r...
# 1  <a href="http://twitter.com/download/iphone" r...
# 2  <a href="http://twitter.com/download/iphone" r...
# 3  <a href="http://twitter.com/download/iphone" r...
# 4  <a href="http://twitter.com/download/iphone" r...
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...                13
# 1  This is Tilly. She's just checking pup on you....                13
# 2  This is Archie. He is a rare Norwegian Pouncin...                12
# 3  This is Darla. She commenced a snooze mid meal...                13
# 4  This is Franklin. He would like you to stop ca...                12
#
#    rating_denominator      name doggo floofer pupper puppo
# 0                  10   Phineas  None    None   None  None
# 1                  10     Tilly  None    None   None  None
# 2                  10    Archie  None    None   None  None
# 3                  10     Darla  None    None   None  None
# 4                  10  Franklin  None    None   None  None

# %% [markdown]
# ### `Define`
# - fix breeds' name by making one new col and drop remain 4 cols

# %% [markdown]
# ### `Code`

# %%
# select the dog stages columns from the dataset
breeds = ['doggo', 'pupper', 'puppo', 'floofer']
# replace the 'None' string with np.nan 
for i in breeds:
    if i in clean_archive.columns:
        clean_archive[breeds] = clean_archive[breeds].replace('None', np.nan)

        # create the type column with joining the four columns in one column dog_stage join for more than stage
        clean_archive['type'] = clean_archive[breeds].apply(lambda x: ', '.join(x.dropna().astype('str')),axis =1)
        # replace the empty string with nan and change datatype to category
        clean_archive.type = clean_archive.type.replace('', np.nan)

        # drop the 4 columns

        clean_archive = clean_archive.drop(columns = breeds, axis =1)
clean_archive.loc[200, "type"] = "floofer"
clean_archive.loc[clean_archive[clean_archive.type == "doggo, puppo"].index,"type"] = "puppo"

# %% [markdown]
# ### `Test`

# %%
clean_archive.type.value_counts()
# Out:
# pupper           201
# doggo             63
# puppo             23
# floofer            8
# doggo, pupper      8
# Name: type, dtype: int64

# %% [markdown]
# ### `Define`
# #### change name col values
#     - get untitled names in clean_archive df then assign that name to "NaN"
#     - get lower names in clean_archive df then assign that name to "NaN"

# %% [markdown]
# ### `code`

# %%
# get untitled an lower names from archive df 
untitled = clean_archive.name.loc[clean_archive.name.str.istitle() == False].unique()
lowers = clean_archive.name.loc[clean_archive.name.str.islower()].unique()

l = np.concatenate((untitled,lowers),axis=0)
l = np.unique(l).tolist()[5:]
clean_archive.loc[clean_archive.name.apply(lambda x: x in l), "name"] = np.nan
clean_archive.loc[clean_archive[clean_archive.name == "None"].index,"name"] = np.nan

# %% [markdown]
# ### `Test`

# %%
clean_archive.sample()
# Out:
#                 tweet_id                  timestamp  \
# 2172  669327207240699904  2015-11-25 01:30:16 +0000
#
#                                                  source  \
# 2172  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  rating_numerator  \
# 2172  Just got home from college. Dis my dog. She do...                13
#
#       rating_denominator name type
# 2172                  10  NaN  NaN

# %% [markdown]
# ### Define
# - extract name from text

# %% [markdown]
# ### `Code`

# %%
clean_archive["name"] = clean_archive.text.str.extract('((This is|Meet) ([A-Z][a-z]*)\\.)', expand=True)[2]

# %% [markdown]
# ### `Test`

# %%
clean_archive.sample(5)
# Out:
#                 tweet_id                  timestamp  \
# 1748  679062614270468097  2015-12-21 22:15:18 +0000
# 2053  671485057807351808  2015-12-01 00:24:48 +0000
# 797   773191612633579521  2016-09-06 16:10:20 +0000
# 1500  692158366030913536  2016-01-27 01:33:08 +0000
# 76    878057613040115712  2017-06-23 01:10:23 +0000
#
#                                                  source  \
# 1748  <a href="http://twitter.com/download/iphone" r...
# 2053  <a href="http://twitter.com/download/iphone" r...
# 797   <a href="http://twitter.com/download/iphone" r...
# 1500  <a href="http://twitter.com/download/iphone" r...
# 76    <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  rating_numerator  \
# 1748  This is Chompsky. He lives up to his name. 11/...                11
# 2053  Meet Penelope. She is a white Macadamias Duode...                11
# 797   This is Grey. He's the dogtor in charge of you...                12
# 1500  This is Edgar. He's a Sassafras Puggleflash. N...                10
# 76    This is Emmy. She was adopted today. Massive r...                14
#
#       rating_denominator      name type
# 1748                  10  Chompsky  NaN
# 2053                  10  Penelope  NaN
# 797                   10      Grey  NaN
# 1500                  10     Edgar  NaN
# 76                    10      Emmy  NaN

# %%
clean_archive.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1971 entries, 0 to 2355
# Data columns (total 8 columns):
# tweet_id              1971 non-null int64
# timestamp             1971 non-null object
# source                1971 non-null object
# text                  1971 non-null object
# rating_numerator      1971 non-null int64
# rating_denominator    1971 non-null int64
# name                  1178 non-null object
# type                  303 non-null object
# dtypes: int64(3), object(5)
# memory usage: 218.6+ KB

# %% [markdown]
# ### `Define`
# - extract rating_numerator and rating_denominator if a rating_denominator is more than 10
# - deal with rate

# %% [markdown]
# ### `Code`

# %%
# get indexes and extract dog rate from text that its rating_numerator is more than 20 which should be have more than
# one dog
rate = clean_archive[clean_archive["rating_numerator"] > 20 ].text.str.extract('(\d+[.]{1}\d+[/]\d+|(\d+[/]\d+))')[0].tolist()
de = clean_archive[clean_archive["rating_numerator"] > 20 ].text.str.extract('(\d+[.]{1}\d+[/]\d+|(\d+[/]\d+))')[0].index

# %%
# only fix index 1068 manually
clean_archive.loc[1068, "rating_numerator"] = 14
clean_archive.loc[1068, "rating_denominator"] = 10

# change dtype of rating_denominator and rating_numerator
clean_archive.rating_numerator = clean_archive.rating_numerator.astype("float64")
clean_archive.rating_denominator = clean_archive.rating_denominator.astype("float64")
clean_archive.rating_numerator.loc[1068]

# set all rating_denominator values to 10
clean_archive.rating_denominator = 10

# fix indexes values from previous list de
for i,j in zip(de, rate):
    if clean_archive.loc[i, "rating_numerator"] >10:
        clean_archive.loc[i, "rating_numerator"] = round(( float(j.split('/')[0]) / ( float(j.split('/')[1]) / 10)), 1)
    clean_archive.loc[i, "rating_denominator"] = 10.0

# %% [markdown]
# ### `Test`

# %%
# test gathered rate
clean_archive.loc[de]
# Out:
#                 tweet_id                  timestamp  \
# 433   820690176645140481  2017-01-15 17:52:40 +0000
# 516   810984652412424192  2016-12-19 23:06:23 +0000
# 695   786709082849828864  2016-10-13 23:23:56 +0000
# 763   778027034220126208  2016-09-20 00:24:34 +0000
# 902   758467244762497024  2016-07-28 01:00:57 +0000
# 979   749981277374128128  2016-07-04 15:00:45 +0000
# 1120  731156023742988288  2016-05-13 16:15:54 +0000
# 1202  716439118184652801  2016-04-03 01:36:11 +0000
# 1228  713900603437621249  2016-03-27 01:29:02 +0000
# 1254  710658690886586372  2016-03-18 02:46:49 +0000
# 1274  709198395643068416  2016-03-14 02:04:08 +0000
# 1351  704054845121142784  2016-02-28 21:25:30 +0000
# 1433  697463031882764288  2016-02-10 16:51:59 +0000
# 1635  684222868335505415  2016-01-05 04:00:18 +0000
# 1712  680494726643068929  2015-12-25 21:06:00 +0000
# 1779  677716515794329600  2015-12-18 05:06:23 +0000
# 1843  675853064436391936  2015-12-13 01:41:41 +0000
# 2074  670842764863651840  2015-11-29 05:52:33 +0000
#
#                                                  source  \
# 433   <a href="http://twitter.com/download/iphone" r...
# 516   <a href="http://twitter.com/download/iphone" r...
# 695   <a href="http://twitter.com/download/iphone" r...
# 763   <a href="http://twitter.com/download/iphone" r...
# 902   <a href="http://twitter.com/download/iphone" r...
# 979   <a href="https://about.twitter.com/products/tw...
# 1120  <a href="http://twitter.com/download/iphone" r...
# 1202  <a href="http://twitter.com/download/iphone" r...
# 1228  <a href="http://twitter.com/download/iphone" r...
# 1254  <a href="http://twitter.com/download/iphone" r...
# 1274  <a href="http://twitter.com/download/iphone" r...
# 1351  <a href="http://twitter.com/download/iphone" r...
# 1433  <a href="http://twitter.com/download/iphone" r...
# 1635  <a href="http://twitter.com/download/iphone" r...
# 1712  <a href="http://twitter.com/download/iphone" r...
# 1779  <a href="http://twitter.com/download/iphone" r...
# 1843  <a href="http://twitter.com/download/iphone" r...
# 2074  <a href="http://twitter.com/download/iphone" r...
#
#                                                    text  rating_numerator  \
# 433   The floofs have been released I repeat the flo...              12.0
# 516   Meet Sam. She smiles 24/7 &amp; secretly aspir...              34.3
# 695   This is Logan, the Chow who lived. He solemnly...               9.8
# 763   This is Sophie. She's a Jubilant Bush Pupper. ...              11.3
# 902   Why does this never happen at my front door......              11.0
# 979   This is Atticus. He's quite simply America af....            1776.0
# 1120  Say hello to this unbelievably well behaved sq...              12.0
# 1202  This is Bluebert. He just saw that both #Final...              10.0
# 1228  Happy Saturday here's 9 puppers on a bench. 99...              11.0
# 1254  Here's a brigade of puppers. All look very pre...              10.0
# 1274  From left to right:\nCletus, Jerome, Alejandro...               9.0
# 1351  Here is a whole flock of puppers.  60/50 I'll ...              12.0
# 1433  Happy Wednesday here's a bucket of pups. 44/40...              11.0
# 1635  Someone help the girl is being mugged. Several...              11.0
# 1712  Here we have uncovered an entire battalion of ...              11.3
# 1779  IT'S PUPPERGEDDON. Total of 144/120 ...I think...              12.0
# 1843  Here we have an entire platoon of puppers. Tot...              11.0
# 2074  After so many requests... here you go.\n\nGood...             420.0
#
#       rating_denominator      name    type
# 433                 10.0       NaN     NaN
# 516                 10.0       Sam     NaN
# 695                 10.0       NaN     NaN
# 763                 10.0    Sophie  pupper
# 902                 10.0       NaN     NaN
# 979                 10.0   Atticus     NaN
# 1120                10.0       NaN     NaN
# 1202                10.0  Bluebert     NaN
# 1228                10.0       NaN     NaN
# 1254                10.0       NaN     NaN
# 1274                10.0       NaN     NaN
# 1351                10.0       NaN     NaN
# 1433                10.0       NaN     NaN
# 1635                10.0       NaN     NaN
# 1712                10.0       NaN     NaN
# 1779                10.0       NaN     NaN
# 1843                10.0       NaN     NaN
# 2074                10.0       NaN     NaN

# %%
clean_archive.rating_numerator.value_counts()
# Out:
# 12.0      450
# 10.0      419
# 11.0      397
# 13.0      253
# 9.0       150
# 8.0        95
# 7.0        52
# 14.0       34
# 5.0        33
# 6.0        32
# 3.0        19
# 4.0        16
# 2.0         9
# 1.0         5
# 11.3        2
# 9.8         1
# 0.0         1
# 1776.0      1
# 420.0       1
# 34.3        1
# Name: rating_numerator, dtype: int64

# %%
clean_image_p.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                      p1   p1_conf  p1_dog                  p2  \
# 0        1  Welsh_springer_spaniel  0.465074    True              collie
# 1        1                 redbone  0.506826    True  miniature_pinscher
# 2        1         German_shepherd  0.596461    True            malinois
# 3        1     Rhodesian_ridgeback  0.408143    True             redbone
# 4        1      miniature_pinscher  0.560311    True          Rottweiler
#
#     p2_conf  p2_dog                   p3   p3_conf  p3_dog
# 0  0.156665    True    Shetland_sheepdog  0.061428    True
# 1  0.074192    True  Rhodesian_ridgeback  0.072010    True
# 2  0.138584    True           bloodhound  0.116197    True
# 3  0.360687    True   miniature_pinscher  0.222752    True
# 4  0.243682    True             Doberman  0.154629    True

# %% [markdown]
# ### `Define`
# - fix source col in clean_archive df

# %% [markdown]
# ### `Code`

# %%
clean_archive.source = clean_archive.source.str.extract(r'(?!for\b)([^>]*([A-Z])\w+)')[0]

# %% [markdown]
# ### `Test`

# %%
clean_archive.source.value_counts()
# Out:
# Twitter for iPhone    1932
# Twitter Web Client      28
# TweetDeck               11
# Name: source, dtype: int64

# %% [markdown]
# ### Define
# - rename cols in clean_image_p df

# %% [markdown]
# ### `Code`

# %%
cols = ['tweet_id', 'jpg_url', 'img_num', 
       'prediction_1', 'confidence_1', 'breed_1',
       'prediction_2', 'confidence_2', 'breed_2',
       'prediction_3', 'confidence_3', 'breed_3']
clean_image_p.columns = cols

# %% [markdown]
# ### `Test`

# %%
clean_image_p.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num            prediction_1  confidence_1  breed_1        prediction_2  \
# 0        1  Welsh_springer_spaniel      0.465074     True              collie
# 1        1                 redbone      0.506826     True  miniature_pinscher
# 2        1         German_shepherd      0.596461     True            malinois
# 3        1     Rhodesian_ridgeback      0.408143     True             redbone
# 4        1      miniature_pinscher      0.560311     True          Rottweiler
#
#    confidence_2  breed_2         prediction_3  confidence_3  breed_3
# 0      0.156665     True    Shetland_sheepdog      0.061428     True
# 1      0.074192     True  Rhodesian_ridgeback      0.072010     True
# 2      0.138584     True           bloodhound      0.116197     True
# 3      0.360687     True   miniature_pinscher      0.222752     True
# 4      0.243682     True             Doberman      0.154629     True

# %% [markdown]
# ### Define
# - get breed name and confidence from clean_image_p df to avoid values in headers issue

# %% [markdown]
# ### `Code`

# %%
#run one time
conf = []
bree = []
idd = []
tmp = pd.DataFrame()
def get_conf_breed(data):
    
    if data.breed_1:
        conf.append(data.confidence_1)
        bree.append(data.prediction_1)
        idd.append(data.tweet_id)
    
    elif data.breed_2:
        conf.append(data.confidence_2)
        bree.append(data.prediction_2)
        idd.append(data.tweet_id)
    
    elif data.breed_3:
        conf.append(data.confidence_3)
        bree.append(data.prediction_3)
        idd.append(data.tweet_id)
        
    else:
        conf.append(0)
        bree.append(np.nan)
        idd.append(data.tweet_id)


clean_image_p.apply(get_conf_breed, axis=1)
        
tmp["tweet_id"]= idd
tmp["breed"] = bree
tmp["prediction_conf"] = conf

# %% [markdown]
# ### `Test`

# %%
# tmp df is clean data from clean_image_p df predictions
tmp.head()
# Out:
#              tweet_id                   breed  prediction_conf
# 0  666020888022790149  Welsh_springer_spaniel         0.465074
# 1  666029285002620928                 redbone         0.506826
# 2  666033412701032449         German_shepherd         0.596461
# 3  666044226329800704     Rhodesian_ridgeback         0.408143
# 4  666049248165822465      miniature_pinscher         0.560311

# %% [markdown]
# ### Define
# - drop unimportant cols in clean_image_p df and merge tmp df instead

# %% [markdown]
# ### `Code`

# %%
clean_image_p = clean_image_p.drop(["prediction_1", "confidence_1", "breed_1","prediction_2", "confidence_2", "breed_2", "prediction_3",\
           "confidence_3", "breed_3"],axis=1)

clean_image_p = pd.merge(clean_image_p,tmp, on="tweet_id")

# %% [markdown]
# ### `Test`

# %%
clean_image_p.head()
# Out:
#              tweet_id                                          jpg_url  \
# 0  666020888022790149  https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
# 1  666029285002620928  https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 2  666033412701032449  https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 3  666044226329800704  https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 4  666049248165822465  https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
#
#    img_num                   breed  prediction_conf
# 0        1  Welsh_springer_spaniel         0.465074
# 1        1                 redbone         0.506826
# 2        1         German_shepherd         0.596461
# 3        1     Rhodesian_ridgeback         0.408143
# 4        1      miniature_pinscher         0.560311

# %% [markdown]
# ### Define
# - merge clean_image_p and clean_json and clean_archive df in twitter_archive_master df

# %% [markdown]
# ### `Code`

# %%
twitter_archive_master = pd.merge(clean_archive, clean_image_p, on="tweet_id")
twitter_archive_master = pd.merge(twitter_archive_master, clean_json, on="tweet_id")

# %% [markdown]
# ### `Test`

# %%
twitter_archive_master.head()
# Out:
#              tweet_id                  timestamp              source  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000  Twitter for iPhone
# 1  892177421306343426  2017-08-01 00:17:27 +0000  Twitter for iPhone
# 2  891815181378084864  2017-07-31 00:18:03 +0000  Twitter for iPhone
# 3  891689557279858688  2017-07-30 15:58:51 +0000  Twitter for iPhone
# 4  891327558926688256  2017-07-29 16:00:24 +0000  Twitter for iPhone
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...              13.0
# 1  This is Tilly. She's just checking pup on you....              13.0
# 2  This is Archie. He is a rare Norwegian Pouncin...              12.0
# 3  This is Darla. She commenced a snooze mid meal...              13.0
# 4  This is Franklin. He would like you to stop ca...              12.0
#
#    rating_denominator      name type  \
# 0                10.0   Phineas  NaN
# 1                10.0     Tilly  NaN
# 2                10.0    Archie  NaN
# 3                10.0     Darla  NaN
# 4                10.0  Franklin  NaN
#
#                                            jpg_url  img_num  \
# 0  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg        1
# 1  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg        1
# 2  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg        1
# 3  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg        1
# 4  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg        2
#
#                 breed  prediction_conf  retweet_count  fav_count
# 0                 NaN         0.000000           8853      39467
# 1           Chihuahua         0.323581           6514      33819
# 2           Chihuahua         0.716012           4328      25461
# 3  Labrador_retriever         0.168086           8964      42908
# 4              basset         0.555712           9774      41048

# %% [markdown]
# ### `Define`
# - **drop the row that has sentence "We only rate dogs" this tweet's image doesn't include dogs**

# %% [markdown]
# ### `Code`

# %%
twitter_archive_master.drop(\
  twitter_archive_master[twitter_archive_master.text.apply(lambda x: "We only rate dogs" in x)].index,axis=0,inplace=True)

# %% [markdown]
# ### `Test`

# %%
#insure that non-dogs tweets is removed
twitter_archive_master[twitter_archive_master.text.apply(lambda x: "We only rate dogs" in x)].index
# Out:
# Int64Index([], dtype='int64')

# %% [markdown]
# ### Define
# - replace None values to Nan in type and name columns

# %% [markdown]
# ### `Code`

# %%
twitter_archive_master.type = twitter_archive_master.type.replace(to_replace = "None", value=np.nan)
twitter_archive_master.name = twitter_archive_master.name.replace(to_replace = "None", value=np.nan)

# %% [markdown]
# ### `Test`

# %%
twitter_archive_master.head()
# Out:
#              tweet_id                  timestamp              source  \
# 0  892420643555336193  2017-08-01 16:23:56 +0000  Twitter for iPhone
# 1  892177421306343426  2017-08-01 00:17:27 +0000  Twitter for iPhone
# 2  891815181378084864  2017-07-31 00:18:03 +0000  Twitter for iPhone
# 3  891689557279858688  2017-07-30 15:58:51 +0000  Twitter for iPhone
# 4  891327558926688256  2017-07-29 16:00:24 +0000  Twitter for iPhone
#
#                                                 text  rating_numerator  \
# 0  This is Phineas. He's a mystical boy. Only eve...              13.0
# 1  This is Tilly. She's just checking pup on you....              13.0
# 2  This is Archie. He is a rare Norwegian Pouncin...              12.0
# 3  This is Darla. She commenced a snooze mid meal...              13.0
# 4  This is Franklin. He would like you to stop ca...              12.0
#
#    rating_denominator      name type  \
# 0                10.0   Phineas  NaN
# 1                10.0     Tilly  NaN
# 2                10.0    Archie  NaN
# 3                10.0     Darla  NaN
# 4                10.0  Franklin  NaN
#
#                                            jpg_url  img_num  \
# 0  https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg        1
# 1  https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg        1
# 2  https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg        1
# 3  https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg        1
# 4  https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg        2
#
#                 breed  prediction_conf  retweet_count  fav_count
# 0                 NaN         0.000000           8853      39467
# 1           Chihuahua         0.323581           6514      33819
# 2           Chihuahua         0.716012           4328      25461
# 3  Labrador_retriever         0.168086           8964      42908
# 4              basset         0.555712           9774      41048

# %% [markdown]
# ### Define
# - drop rating_denominator col from twitter_archive_master it's a known fixed number
# - drop img_num col from twitter_archive_master not needed in analysis

# %% [markdown]
# ### `Code`

# %%
twitter_archive_master = twitter_archive_master.drop(["rating_denominator","img_num"], axis=1)

# %%
twitter_archive_master = twitter_archive_master.reset_index()
twitter_archive_master = twitter_archive_master.drop("index",axis=1)

# %% [markdown]
# ### `Test`

# %%
twitter_archive_master.sample()
# Out:
#                tweet_id                  timestamp              source  \
# 161  849412302885593088  2017-04-05 00:04:08 +0000  Twitter for iPhone
#
#                                                   text  rating_numerator  \
# 161  This is Noosh. He noticed you were in the show...              12.0
#
#       name type                                          jpg_url       breed  \
# 161  Noosh  NaN  https://pbs.twimg.com/media/C8m3-iQVoAAETnF.jpg  schipperke
#
#      prediction_conf  retweet_count  fav_count
# 161         0.907559           3487      17039

# %% [markdown]
# ### Define
# - remove a row has no name&type&breed & numerator >100 (ex: twitter_archive_master.rating_numerator == 420.0 not a dog)

# %% [markdown]
# ### `Code`

# %%
x = twitter_archive_master.apply(\
lambda x:  (x["rating_numerator"] > 100) & (pd.isnull(x["breed"])) & (pd.isnull(x["name"])) & (pd.isnull(x["type"])),axis=1)

twitter_archive_master.drop(twitter_archive_master[x].index,axis=0, inplace=True)

# %% [markdown]
# ### `Test`

# %%
twitter_archive_master.sample(5)
# Out:
#                 tweet_id                  timestamp              source  \
# 1207  686947101016735744  2016-01-12 16:25:26 +0000  Twitter for iPhone
# 1047  699801817392291840  2016-02-17 03:45:29 +0000  Twitter for iPhone
# 1199  687460506001633280  2016-01-14 02:25:31 +0000  Twitter for iPhone
# 882   717009362452090881  2016-04-04 15:22:08 +0000  Twitter for iPhone
# 440   793256262322548741  2016-11-01 01:00:05 +0000  Twitter for iPhone
#
#                                                    text  rating_numerator  \
# 1207  This is Jackson. He was specifically told not ...              11.0
# 1047  This is Cooper. He began to tear up when his b...              11.0
# 1199  This is Kramer. He's a Picasso Tortellini. Tie...              10.0
# 882   This is Smokey. He's having some sort of exist...              10.0
# 440   Oh h*ck look at this spookling right here. Fri...              12.0
#
#          name    type                                          jpg_url  \
# 1207  Jackson     NaN  https://pbs.twimg.com/media/CYiGvn-UwAEe4wL.jpg
# 1047   Cooper  pupper  https://pbs.twimg.com/media/CbYyCMcWIAAHHjF.jpg
# 1199   Kramer     NaN  https://pbs.twimg.com/media/CYpZrtDWwAE8Kpw.jpg
# 882    Smokey  pupper  https://pbs.twimg.com/media/CfNUNetW8AAekHx.jpg
# 440       NaN     NaN  https://pbs.twimg.com/media/CwI2XCvXEAEO8mc.jpg
#
#                  breed  prediction_conf  retweet_count  fav_count
# 1207               NaN         0.000000           3582       9433
# 1047  golden_retriever         0.808978           1088       3345
# 1199       Boston_bull         0.223366            614       2243
# 882     Siberian_husky         0.506154           1102       3583
# 440             basset         0.207622           9714      22350

# %%
# row has no name&type&breed & numerator >100 and not a dog
twitter_archive_master[twitter_archive_master.rating_numerator == 420.0]
# Out:
# Empty DataFrame
# Columns: [tweet_id, timestamp, source, text, rating_numerator, name, type, jpg_url, breed, prediction_conf, retweet_count, fav_count]
# Index: []

# %% [markdown]
# ### Define
# - change tweet id dtype to

# %% [markdown]
# ### `Code`

# %%
twitter_archive_master.tweet_id = twitter_archive_master.astype({'tweet_id': 'object'})

# %% [markdown]
# ### `Test`

# %%
twitter_archive_master.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 1922 entries, 0 to 1922
# Data columns (total 12 columns):
# tweet_id            1922 non-null object
# timestamp           1922 non-null object
# source              1922 non-null object
# text                1922 non-null object
# rating_numerator    1922 non-null float64
# name                1178 non-null object
# type                303 non-null object
# jpg_url             1922 non-null object
# breed               1622 non-null object
# prediction_conf     1922 non-null float64
# retweet_count       1922 non-null int64
# fav_count           1922 non-null int64
# dtypes: float64(2), int64(2), object(8)
# memory usage: 195.2+ KB

# %% [markdown]
# ### Define
# - reset index in twitter_archive_master df

# %% [markdown]
# ### `Code`

# %%
twitter_archive_master = twitter_archive_master.reset_index()
twitter_archive_master = twitter_archive_master.drop("index",axis=1)

# %% [markdown]
# ### `Test`

# %%
twitter_archive_master
# Out:
#                 tweet_id                  timestamp              source  \
# 0     892420643555336193  2017-08-01 16:23:56 +0000  Twitter for iPhone
# 1     892177421306343426  2017-08-01 00:17:27 +0000  Twitter for iPhone
# 2     891815181378084864  2017-07-31 00:18:03 +0000  Twitter for iPhone
# 3     891689557279858688  2017-07-30 15:58:51 +0000  Twitter for iPhone
# 4     891327558926688256  2017-07-29 16:00:24 +0000  Twitter for iPhone
# 5     891087950875897856  2017-07-29 00:08:17 +0000  Twitter for iPhone
# 6     890971913173991426  2017-07-28 16:27:12 +0000  Twitter for iPhone
# 7     890729181411237888  2017-07-28 00:22:40 +0000  Twitter for iPhone
# 8     890609185150312448  2017-07-27 16:25:51 +0000  Twitter for iPhone
# 9     890240255349198849  2017-07-26 15:59:51 +0000  Twitter for iPhone
# 10    890006608113172480  2017-07-26 00:31:25 +0000  Twitter for iPhone
# 11    889880896479866881  2017-07-25 16:11:53 +0000  Twitter for iPhone
# 12    889665388333682689  2017-07-25 01:55:32 +0000  Twitter for iPhone
# 13    889638837579907072  2017-07-25 00:10:02 +0000  Twitter for iPhone
# 14    889531135344209921  2017-07-24 17:02:04 +0000  Twitter for iPhone
# 15    889278841981685760  2017-07-24 00:19:32 +0000  Twitter for iPhone
# 16    888917238123831296  2017-07-23 00:22:39 +0000  Twitter for iPhone
# 17    888804989199671297  2017-07-22 16:56:37 +0000  Twitter for iPhone
# 18    888554962724278272  2017-07-22 00:23:06 +0000  Twitter for iPhone
# 19    888078434458587136  2017-07-20 16:49:33 +0000  Twitter for iPhone
# 20    887705289381826560  2017-07-19 16:06:48 +0000  Twitter for iPhone
# 21    887517139158093824  2017-07-19 03:39:09 +0000  Twitter for iPhone
# 22    887473957103951883  2017-07-19 00:47:34 +0000  Twitter for iPhone
# 23    887343217045368832  2017-07-18 16:08:03 +0000  Twitter for iPhone
# 24    886983233522544640  2017-07-17 16:17:36 +0000  Twitter for iPhone
# 25    886736880519319552  2017-07-16 23:58:41 +0000  Twitter for iPhone
# 26    886680336477933568  2017-07-16 20:14:00 +0000  Twitter for iPhone
# 27    886366144734445568  2017-07-15 23:25:31 +0000  Twitter for iPhone
# 28    886258384151887873  2017-07-15 16:17:19 +0000  Twitter for iPhone
# 29    885984800019947520  2017-07-14 22:10:11 +0000  Twitter for iPhone
# ...                  ...                        ...                 ...
# 1892  666411507551481857  2015-11-17 00:24:19 +0000  Twitter for iPhone
# 1893  666407126856765440  2015-11-17 00:06:54 +0000  Twitter for iPhone
# 1894  666396247373291520  2015-11-16 23:23:41 +0000  Twitter for iPhone
# 1895  666373753744588802  2015-11-16 21:54:18 +0000  Twitter for iPhone
# 1896  666362758909284353  2015-11-16 21:10:36 +0000  Twitter for iPhone
# 1897  666353288456101888  2015-11-16 20:32:58 +0000  Twitter for iPhone
# 1898  666345417576210432  2015-11-16 20:01:42 +0000  Twitter for iPhone
# 1899  666337882303524864  2015-11-16 19:31:45 +0000  Twitter for iPhone
# 1900  666293911632134144  2015-11-16 16:37:02 +0000  Twitter for iPhone
# 1901  666287406224695296  2015-11-16 16:11:11 +0000  Twitter for iPhone
# 1902  666273097616637952  2015-11-16 15:14:19 +0000  Twitter for iPhone
# 1903  666268910803644416  2015-11-16 14:57:41 +0000  Twitter for iPhone
# 1904  666104133288665088  2015-11-16 04:02:55 +0000  Twitter for iPhone
# 1905  666102155909144576  2015-11-16 03:55:04 +0000  Twitter for iPhone
# 1906  666099513787052032  2015-11-16 03:44:34 +0000  Twitter for iPhone
# 1907  666094000022159362  2015-11-16 03:22:39 +0000  Twitter for iPhone
# 1908  666082916733198337  2015-11-16 02:38:37 +0000  Twitter for iPhone
# 1909  666073100786774016  2015-11-16 01:59:36 +0000  Twitter for iPhone
# 1910  666071193221509120  2015-11-16 01:52:02 +0000  Twitter for iPhone
# 1911  666063827256086533  2015-11-16 01:22:45 +0000  Twitter for iPhone
# 1912  666058600524156928  2015-11-16 01:01:59 +0000  Twitter for iPhone
# 1913  666057090499244032  2015-11-16 00:55:59 +0000  Twitter for iPhone
# 1914  666055525042405380  2015-11-16 00:49:46 +0000  Twitter for iPhone
# 1915  666051853826850816  2015-11-16 00:35:11 +0000  Twitter for iPhone
# 1916  666050758794694657  2015-11-16 00:30:50 +0000  Twitter for iPhone
# 1917  666049248165822465  2015-11-16 00:24:50 +0000  Twitter for iPhone
# 1918  666044226329800704  2015-11-16 00:04:52 +0000  Twitter for iPhone
# 1919  666033412701032449  2015-11-15 23:21:54 +0000  Twitter for iPhone
# 1920  666029285002620928  2015-11-15 23:05:30 +0000  Twitter for iPhone
# 1921  666020888022790149  2015-11-15 22:32:08 +0000  Twitter for iPhone
#
#                                                    text  rating_numerator  \
# 0     This is Phineas. He's a mystical boy. Only eve...              13.0
# 1     This is Tilly. She's just checking pup on you....              13.0
# 2     This is Archie. He is a rare Norwegian Pouncin...              12.0
# 3     This is Darla. She commenced a snooze mid meal...              13.0
# 4     This is Franklin. He would like you to stop ca...              12.0
# 5     Here we have a majestic great white breaching ...              13.0
# 6     Meet Jax. He enjoys ice cream so much he gets ...              13.0
# 7     When you watch your owner call another dog a g...              13.0
# 8     This is Zoey. She doesn't want to be one of th...              13.0
# 9     This is Cassie. She is a college pup. Studying...              14.0
# 10    This is Koda. He is a South Australian decksha...              13.0
# 11    This is Bruno. He is a service shark. Only get...              13.0
# 12    Here's a puppo that seems to be on the fence a...              13.0
# 13    This is Ted. He does his best. Sometimes that'...              12.0
# 14    This is Stuart. He's sporting his favorite fan...              13.0
# 15    This is Oliver. You're witnessing one of his m...              13.0
# 16    This is Jim. He found a fren. Taught him how t...              12.0
# 17    This is Zeke. He has a new stick. Very proud o...              13.0
# 18    This is Ralphus. He's powering up. Attempting ...              13.0
# 19    This is Gerald. He was just told he didn't get...              12.0
# 20    This is Jeffrey. He has a monopoly on the pool...              13.0
# 21    I've yet to rate a Venezuelan Hover Wiener. Th...              14.0
# 22    This is Canela. She attempted some fancy porch...              13.0
# 23    You may not have known you needed to see this ...              13.0
# 24    This is Maya. She's very shy. Rarely leaves he...              13.0
# 25    This is Mingus. He's a wonderful father to his...              13.0
# 26    This is Derek. He's late for a dog meeting. 13...              13.0
# 27    This is Roscoe. Another pupper fallen victim t...              12.0
# 28    This is Waffles. His doggles are pupside down....              13.0
# 29    Viewer discretion advised. This is Jimbo. He w...              12.0
# ...                                                 ...               ...
# 1892  This is quite the dog. Gets really excited whe...               2.0
# 1893  This is a southern Vesuvius bumblegruff. Can d...               7.0
# 1894  Oh goodness. A super rare northeast Qdoba kang...               9.0
# 1895  Those are sunglasses and a jean jacket. 11/10 ...              11.0
# 1896  Unique dog here. Very small. Lives in containe...               6.0
# 1897  Here we have a mixed Asiago from the Galápagos...               8.0
# 1898  Look at this jokester thinking seat belt laws ...              10.0
# 1899  This is an extremely rare horned Parthenon. No...               9.0
# 1900  This is a funny dog. Weird toes. Won't come do...               3.0
# 1901  This is an Albanian 3 1/2 legged  Episcopalian...               1.0
# 1902     Can take selfies 11/10 https://t.co/ws2AMaNwPW              11.0
# 1903  Very concerned about fellow dog trapped in com...              10.0
# 1904  Not familiar with this breed. No tail (weird)....               1.0
# 1905  Oh my. Here you are seeing an Adobe Setter giv...              11.0
# 1906  Can stand on stump for what seems like a while...               8.0
# 1907  This appears to be a Mongolian Presbyterian mi...               9.0
# 1908  Here we have a well-established sunblockerspan...               6.0
# 1909  Let's hope this flight isn't Malaysian (lol). ...              10.0
# 1910  Here we have a northern speckled Rhododendron....               9.0
# 1911  This is the happiest dog you will ever see. Ve...              10.0
# 1912  Here is the Rand Paul of retrievers folks! He'...               8.0
# 1913  My oh my. This is a rare blond Canadian terrie...               9.0
# 1914  Here is a Siberian heavily armored polar bear ...              10.0
# 1915  This is an odd dog. Hard on the outside but lo...               2.0
# 1916  This is a truly beautiful English Wilson Staff...              10.0
# 1917  Here we have a 1949 1st generation vulpix. Enj...               5.0
# 1918  This is a purebred Piers Morgan. Loves to Netf...               6.0
# 1919  Here is a very happy pup. Big fan of well-main...               9.0
# 1920  This is a western brown Mitsubishi terrier. Up...               7.0
# 1921  Here we have a Japanese Irish Setter. Lost eye...               8.0
#
#           name    type                                            jpg_url  \
# 0      Phineas     NaN    https://pbs.twimg.com/media/DGKD1-bXoAAIAUK.jpg
# 1        Tilly     NaN    https://pbs.twimg.com/media/DGGmoV4XsAAUL6n.jpg
# 2       Archie     NaN    https://pbs.twimg.com/media/DGBdLU1WsAANxJ9.jpg
# 3        Darla     NaN    https://pbs.twimg.com/media/DF_q7IAWsAEuuN8.jpg
# 4     Franklin     NaN    https://pbs.twimg.com/media/DF6hr6BUMAAzZgT.jpg
# 5          NaN     NaN    https://pbs.twimg.com/media/DF3HwyEWsAABqE6.jpg
# 6          Jax     NaN    https://pbs.twimg.com/media/DF1eOmZXUAALUcq.jpg
# 7          NaN     NaN    https://pbs.twimg.com/media/DFyBahAVwAAhUTd.jpg
# 8         Zoey     NaN    https://pbs.twimg.com/media/DFwUU__XcAEpyXI.jpg
# 9       Cassie   doggo    https://pbs.twimg.com/media/DFrEyVuW0AAO3t9.jpg
# 10        Koda     NaN    https://pbs.twimg.com/media/DFnwSY4WAAAMliS.jpg
# 11       Bruno     NaN    https://pbs.twimg.com/media/DFl99B1WsAITKsg.jpg
# 12         NaN   puppo    https://pbs.twimg.com/media/DFi579UWsAAatzw.jpg
# 13         Ted     NaN    https://pbs.twimg.com/media/DFihzFfXsAYGDPR.jpg
# 14      Stuart   puppo    https://pbs.twimg.com/media/DFg_2PVW0AEHN3p.jpg
# 15      Oliver     NaN  https://pbs.twimg.com/ext_tw_video_thumb/88927...
# 16         Jim     NaN    https://pbs.twimg.com/media/DFYRgsOUQAARGhO.jpg
# 17        Zeke     NaN    https://pbs.twimg.com/media/DFWra-3VYAA2piG.jpg
# 18     Ralphus     NaN    https://pbs.twimg.com/media/DFTH_O-UQAACu20.jpg
# 19      Gerald     NaN    https://pbs.twimg.com/media/DFMWn56WsAAkA7B.jpg
# 20     Jeffrey     NaN    https://pbs.twimg.com/media/DFHDQBbXgAEqY7t.jpg
# 21         NaN     NaN  https://pbs.twimg.com/ext_tw_video_thumb/88751...
# 22      Canela     NaN    https://pbs.twimg.com/media/DFDw2tyUQAAAFke.jpg
# 23         NaN     NaN  https://pbs.twimg.com/ext_tw_video_thumb/88734...
# 24        Maya     NaN    https://pbs.twimg.com/media/DE8yicJW0AAAvBJ.jpg
# 25      Mingus     NaN    https://pbs.twimg.com/media/DE5Se8FXcAAJFx4.jpg
# 26       Derek     NaN    https://pbs.twimg.com/media/DE4fEDzWAAAyHMM.jpg
# 27      Roscoe  pupper    https://pbs.twimg.com/media/DE0BTnQUwAApKEH.jpg
# 28     Waffles     NaN    https://pbs.twimg.com/media/DEyfTG4UMAE4aE9.jpg
# 29       Jimbo     NaN    https://pbs.twimg.com/media/DEumeWWV0AA-Z61.jpg
# ...        ...     ...                                                ...
# 1892       NaN     NaN    https://pbs.twimg.com/media/CT-RugiWIAELEaq.jpg
# 1893       NaN     NaN    https://pbs.twimg.com/media/CT-NvwmW4AAugGZ.jpg
# 1894       NaN     NaN    https://pbs.twimg.com/media/CT-D2ZHWIAA3gK1.jpg
# 1895       NaN     NaN    https://pbs.twimg.com/media/CT9vZEYWUAAlZ05.jpg
# 1896       NaN     NaN    https://pbs.twimg.com/media/CT9lXGsUcAAyUFt.jpg
# 1897       NaN     NaN    https://pbs.twimg.com/media/CT9cx0tUEAAhNN_.jpg
# 1898       NaN     NaN    https://pbs.twimg.com/media/CT9Vn7PWoAA_ZCM.jpg
# 1899       NaN     NaN    https://pbs.twimg.com/media/CT9OwFIWEAMuRje.jpg
# 1900       NaN     NaN    https://pbs.twimg.com/media/CT8mx7KW4AEQu8N.jpg
# 1901       NaN     NaN    https://pbs.twimg.com/media/CT8g3BpUEAAuFjg.jpg
# 1902       NaN     NaN    https://pbs.twimg.com/media/CT8T1mtUwAA3aqm.jpg
# 1903       NaN     NaN    https://pbs.twimg.com/media/CT8QCd1WEAADXws.jpg
# 1904       NaN     NaN    https://pbs.twimg.com/media/CT56LSZWoAAlJj2.jpg
# 1905       NaN     NaN    https://pbs.twimg.com/media/CT54YGiWUAEZnoK.jpg
# 1906       NaN     NaN    https://pbs.twimg.com/media/CT51-JJUEAA6hV8.jpg
# 1907       NaN     NaN    https://pbs.twimg.com/media/CT5w9gUW4AAsBNN.jpg
# 1908       NaN     NaN    https://pbs.twimg.com/media/CT5m4VGWEAAtKc8.jpg
# 1909       NaN     NaN    https://pbs.twimg.com/media/CT5d9DZXAAALcwe.jpg
# 1910       NaN     NaN    https://pbs.twimg.com/media/CT5cN_3WEAAlOoZ.jpg
# 1911       NaN     NaN    https://pbs.twimg.com/media/CT5Vg_wXIAAXfnj.jpg
# 1912       NaN     NaN    https://pbs.twimg.com/media/CT5Qw94XAAA_2dP.jpg
# 1913       NaN     NaN    https://pbs.twimg.com/media/CT5PY90WoAAQGLo.jpg
# 1914       NaN     NaN    https://pbs.twimg.com/media/CT5N9tpXIAAifs1.jpg
# 1915       NaN     NaN    https://pbs.twimg.com/media/CT5KoJ1WoAAJash.jpg
# 1916       NaN     NaN    https://pbs.twimg.com/media/CT5Jof1WUAEuVxN.jpg
# 1917       NaN     NaN    https://pbs.twimg.com/media/CT5IQmsXIAAKY4A.jpg
# 1918       NaN     NaN    https://pbs.twimg.com/media/CT5Dr8HUEAA-lEu.jpg
# 1919       NaN     NaN    https://pbs.twimg.com/media/CT4521TWwAEvMyu.jpg
# 1920       NaN     NaN    https://pbs.twimg.com/media/CT42GRgUYAA5iDo.jpg
# 1921       NaN     NaN    https://pbs.twimg.com/media/CT4udn0WwAA0aMy.jpg
#
#                             breed  prediction_conf  retweet_count  fav_count
# 0                             NaN         0.000000           8853      39467
# 1                       Chihuahua         0.323581           6514      33819
# 2                       Chihuahua         0.716012           4328      25461
# 3              Labrador_retriever         0.168086           8964      42908
# 4                          basset         0.555712           9774      41048
# 5        Chesapeake_Bay_retriever         0.425595           3261      20562
# 6                     Appenzeller         0.341703           2158      12041
# 7                      Pomeranian         0.566142          16716      56848
# 8                   Irish_terrier         0.487574           4429      28226
# 9                        Pembroke         0.511319           7711      32467
# 10                        Samoyed         0.957979           7624      31166
# 11                 French_bulldog         0.377417           5156      28268
# 12                       Pembroke         0.966327           8538      38818
# 13                 French_bulldog         0.991650           4735      27672
# 14               golden_retriever         0.953442           2321      15359
# 15                        whippet         0.626152           5637      25652
# 16               golden_retriever         0.714719           4709      29611
# 17               golden_retriever         0.469760           4559      26080
# 18                 Siberian_husky         0.700377           3732      20290
# 19                 French_bulldog         0.995026           3653      22201
# 20                         basset         0.821664           5609      30779
# 21                            NaN         0.000000          12082      46959
# 22                       Pembroke         0.809197          18781      69871
# 23               Mexican_hairless         0.330741          10737      34222
# 24                      Chihuahua         0.793469           8084      35859
# 25                         kuvasz         0.309706           3443      12306
# 26                            NaN         0.000000           4610      22798
# 27                 French_bulldog         0.999201           3316      21524
# 28                            pug         0.943575           6523      28469
# 29               Blenheim_spaniel         0.972494           7097      33382
# ...                           ...              ...            ...        ...
# 1892                          NaN         0.000000            339        459
# 1893      black-and-tan_coonhound         0.529139             44        113
# 1894                    Chihuahua         0.978108             92        172
# 1895  soft-coated_wheaten_terrier         0.326467            100        194
# 1896                          NaN         0.000000            595        804
# 1897                     malamute         0.336874             77        229
# 1898             golden_retriever         0.858744            146        307
# 1899                 Newfoundland         0.278407             96        204
# 1900                          NaN         0.000000            368        522
# 1901                  Maltese_dog         0.857531             71        152
# 1902            Italian_greyhound         0.176053             82        184
# 1903                          NaN         0.000000             37        108
# 1904                          NaN         0.000000           6871      14765
# 1905               English_setter         0.298617             16         81
# 1906                        Lhasa         0.582330             73        164
# 1907                   bloodhound         0.195217             79        169
# 1908                          pug         0.489814             47        121
# 1909                 Walker_hound         0.260857            174        335
# 1910                Gordon_setter         0.503672             67        154
# 1911             golden_retriever         0.775930            232        496
# 1912             miniature_poodle         0.201493             61        115
# 1913             golden_retriever         0.007959            146        304
# 1914                         chow         0.692517            261        448
# 1915                          NaN         0.000000            879       1253
# 1916         Bernese_mountain_dog         0.651137             60        136
# 1917           miniature_pinscher         0.560311             41        111
# 1918          Rhodesian_ridgeback         0.408143            147        311
# 1919              German_shepherd         0.596461             47        128
# 1920                      redbone         0.506826             48        132
# 1921       Welsh_springer_spaniel         0.465074            532       2535
#
# [1922 rows x 12 columns]

# %% [markdown]
# ### Store twitter_archive_master
# <a id="store"></a>

# %%
# Store twitter_archive_master df as a csv file named "twitter_archive_master.csv"
twitter_archive_master.to_csv('twitter_archive_master.csv',encoding='utf-8',index=False)

# %% [markdown]
# ## Data analysis
# <a id= "analysis"></a>

# %% [markdown]
# ### -  **what is the most source of tweets**

# %%
plt.title("Distribution of Tweets'Source")
val = twitter_archive_master.source.value_counts().sort_values()
val.plot(kind ="bar")
plt.xlabel('Total Tweets')
plt.ylabel('Source');

# %% [markdown]
# #### an overview about the dataset from these statistics we can see that rating_numerator median is 11 and the values don't a large differ because std is somewhat small

# %%
twitter_archive_master.describe()
# Out:
#        rating_numerator  prediction_conf  retweet_count      fav_count
# count       1922.000000      1922.000000    1922.000000    1922.000000
# mean          11.463424         0.464537    2723.006764    8744.088450
# std           40.333073         0.340023    4654.271643   12094.783412
# min            0.000000         0.000000      16.000000      81.000000
# 25%           10.000000         0.139975     618.000000    1896.000000
# 50%           11.000000         0.457141    1336.500000    4032.000000
# 75%           12.000000         0.776559    3151.500000   11206.000000
# max         1776.000000         0.999956   79515.000000  132810.000000

# %% [markdown]
# ### **what is the common name of dogs**

# %%
# analyze only named dogs
val = twitter_archive_master.name.value_counts()[1:11].sort_values(ascending=False)
val.plot(kind="bar")
plt.xlabel('Names')
plt.ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# ### what is the most common breed

# %%
# analyze only named dogs
val = twitter_archive_master.breed.value_counts()[1:11].sort_values(ascending=False)
val.plot(kind="bar")
plt.xlabel('Breed')
plt.ylabel('Frequency')
# Out:
# Text(0,0.5,'Frequency')

# %% [markdown]
# ### what is account statistics
# #### from this analysis we found that account performance and favorit counts are inceasing although retweet counts are decreasing

# %%
y1= twitter_archive_master.fav_count.rolling(window = 100).mean()
# set a 30 days rolling average for retweet count
y2= twitter_archive_master.retweet_count.rolling(window = 100).mean()
x = twitter_archive_master.timestamp
ax1 = plt.axes()
x_axis = ax1.axes.get_xaxis()
x_axis.set_visible(False)
plt.plot(x,y1)
plt.plot(x,y2)
plt.xticks(rotation = 90)
plt.title('100 days Rolling Average Account Performance')
plt.xlabel('Dates')
plt.ylabel('100 days average')
plt.legend(loc=0);

# %% [markdown]
# ### dog types that a have max rate

# %%
twitter_archive_master.groupby(["type"])['rating_numerator','retweet_count','fav_count'].max()[1:]
# Out:
#                rating_numerator  retweet_count  fav_count
# type
# doggo, pupper              13.0          17621      44619
# floofer                    13.0          18497      33345
# pupper                     14.0          32883     106827
# puppo                      14.0          48265     132810

# %% [markdown]
# ### dog types that have min rate

# %%
twitter_archive_master.groupby(["type"])['rating_numerator','retweet_count','fav_count'].min()[1:]
# Out:
#                rating_numerator  retweet_count  fav_count
# type
# doggo, pupper               5.0           1265       4849
# floofer                    10.0            496       2262
# pupper                      3.0            103        693
# puppo                       9.0            716       3277
